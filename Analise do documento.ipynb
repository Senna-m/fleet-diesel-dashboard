# %%
import pandas as pd

# %%
df = pd.read_csv(
    "Abastecimentos - Salvador e litoral norte.csv",
    sep=";"
)

# %%
df.head()
# Out:
#          DATA   VEICULO  TIPO GASOLINA  ALCOOL DIESEL     G�S        KM  \
# 0  17/06/2020  PLQ 6I57  SPIN      NaN     NaN    NaN    11,9  107517.0
# 1  17/06/2020  PLQ 6I57  SPIN      NaN   45,82    NaN     NaN  107514.0
# 2  17/06/2020  PLL 6A56   VAN      NaN     NaN  81,13     NaN  172376.0
# 3  17/06/2020  PLQ 7J90  SPIN      NaN  15,157    NaN     NaN   99461.0
# 4  28/06/2020  PLQ 7J90  SPIN      NaN     NaN    NaN  12,621   99380.0
#
#       VALOR  KM RODADA MEDIA L/KM         cartão  MOTORISTA DESCONTOS
# 0    34,49         NaN       0,00  cartão credito       NaN       NaN
# 1   155,78         NaN       0,00  cartão credito       NaN       NaN
# 2   239,25         NaN       0,00  cartão credito       NaN       NaN
# 3    50,00         NaN       0,00  cartão credito       NaN       NaN
# 4    35,21         NaN       0,00  cartão credito       NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7073 entries, 0 to 7072
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATA        7073 non-null   object
#  1   VEICULO     7070 non-null   object
#  2   TIPO        582 non-null    object
#  3   GASOLINA    474 non-null    object
#  4   ALCOOL      1093 non-null   object
#  5   DIESEL      5486 non-null   object
#  6   G�S         13 non-null     object
#  7   KM          7061 non-null   float64
#  8   VALOR       7072 non-null   object
#  9   KM RODADA   7020 non-null   float64
#  10  MEDIA L/KM  7031 non-null   object
#  11  cartão      7063 non-null   object
#  12  MOTORISTA   5488 non-null   object
#  13  DESCONTOS   3036 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 773.7+ KB

# %%
df = df[["DATA", "VEICULO", "TIPO","GASOLINA", "ALCOOL", "DIESEL", "G�S", "KM", "VALOR", "KM RODADA", "MEDIA L/KM", "cartão ", "MOTORISTA", "DESCONTOS"]]
